# %%
import pandas as pd
data = pd.read_csv('Navjyoti Alumni Data csv.csv')

# %%
data.shape
# Out:
# (115, 34)

# %%
data.head()
# Out:
#    S. No.       Enrollment no. Teacher's Name Name of the student Gender  \
# 0     1.0  NIF-B/CEP/2014/1489      RAJKUMARI             SHAHEEN      F
# 1     2.0  NIF-B/CEP/2018/0220      RAJKUMARI          WALI AHMED      M
# 2     3.0  NIF-B/CEP/2014/1278      RAJKUMARI     TABARAK HUSSAIN      M
# 3     4.0  NIF-B/CEP/2018/0218      RAJKUMARI              ATTIKA      F
# 4     5.0  NIF-B/CEP/2014/1359      RAJKUMARI               GUDIA      F
#
#   Date of Birth Block House No.     Father's name                    Area  \
# 0     15-Mar-02     A        56        RAZI AHMAD  JJ COLONY BAWANA DELHI
# 1      4-Feb-02     A       253         MD.KHALIK  JJ COLONY BAWANA DELHI
# 2     21-Sep-03     A       621  MD. ABDUL MANNAN  JJ COLONY BAWANA DELHI
# 3      4-Oct-01     A       747    LATAE MD.YANYA  JJ COLONY BAWANA DELHI
# 4     27-Mar-04     A   857/861            RAMESH  JJ COLONY BAWANA DELHI
#
#    ...  Follow up status Whatsapp Number Current Status after home visit  \
# ...

# %%
data.columns
# Out:
# Index(['S. No.', 'Enrollment no.', 'Teacher's Name', 'Name of the student',
#        'Gender', 'Date of Birth', 'Block', 'House No.', 'Father's name',
#        'Area', 'Contact No.', 'Year of passing class X',
#        'Result Status - Class X', 'Marks obtained in class X',
#        'Current Status of X passed out', 'Stream in class XI',
#        'Year of passing class XI', 'Marks obtained in class XI',
#        'Current Status of XI passed out', 'Stream in class XII', 'Roll no.',
#        'Year of passing class XII', 'Marks obtained in class XII',
#        'Year & Month of Follow up', 'Follow up status', 'Whatsapp Number',
#        'Current Status after home visit', 'Year & Month of Follow up.1',
#        'Follow up status.1', 'Current Status after home visit.1',
#        'Year & Month of Follow up.2', 'Follow up status.2',
#        'Current Status after home visit.2', 'Remarks'],
#       dtype='object')

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(data,title='Alumni Data prediction', explorative = True)

# %%
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.11.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-03-31 05:05:16.210650&quot;&gt;&lt;title&gt;Alumni Data prediction&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
profile.to_widgets()
# Out:
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
profile.to_file("output.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
